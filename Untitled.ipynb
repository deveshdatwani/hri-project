# %%
from matplotlib import pyplot as plt

# %%
from numpy import loadtxt

# %%
gesture = loadtxt("gesturecontroller.txt")
ps = loadtxt("ps4controller.txt")

# %%
plt.xlim([-2,2])
plt.ylabel("Time (in seconds)")
plt.xticks([])
plt.scatter([-1,-1,-1,-1,-1,-1,-1,-1], gesture, color="red")
plt.scatter([1,1,1,1,1,1,1,1], ps, color="green")
plt.show()
